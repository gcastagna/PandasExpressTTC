# %%
import pandas as pd

# %% [markdown]
# Daily data accessed from: https://climatedata.ca/download/#station-download
#
# Hourly data accessed from: https://climate-change.canada.ca/climate-data/#/hourly-climate-data

# %% [markdown]
# Explore single daily date file:

# %%
df_daily_weather = pd.read_csv('weather_daily.csv')

# %%
df_daily_weather.info()

print("\nThis dataframe has "+str(len(df_daily_weather))+ ' rows\n')

print('there are '+ str(len(set(df_daily_weather['LOCAL_DATE']))) + ' unique days in this dataframe\n')

df_daily_weather.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   x                         416 non-null    float64
#  1   y                         416 non-null    float64
#  2   MEAN_TEMPERATURE_FLAG     0 non-null      float64
#  3   DIRECTION_MAX_GUST        0 non-null      float64
#  4   MIN_REL_HUMIDITY          0 non-null      float64
#  5   COOLING_DEGREE_DAYS       0 non-null      float64
#  6   MIN_TEMPERATURE           0 non-null      float64
#  7   DIRECTION_MAX_GUST_FLAG   0 non-null      float64
#  8   ID                        416 non-null    object
#  9   MIN_REL_HUMIDITY_FLAG     0 non-null      float64
#  10  SPEED_MAX_GUST            0 non-null      float64
#  11  MAX_REL_HUMIDITY_FLAG     0 non-null      float64
#  12  CLIMATE_IDENTIFIER        416 non-null    int64
# ...

# %% [markdown]
# Looks like this is the daily average or cumulative

# %% [markdown]
# Lets look at one of the hourly files:

# %%
df_hourly_weather = pd.read_csv('climate-hourly (12).csv')
df_hourly_weather['UTC_DATE'] = pd.to_datetime(df_hourly_weather['UTC_DATE'])

# %%
df_hourly_weather.info()

print("\nThis dataframe has "+str(len(df_hourly_weather))+ ' rows\n')

print('there are '+ str(len(set(df_hourly_weather['LOCAL_DAY']))) + ' unique days in this dataframe\n')

print('Data for this batch is available between '+ str(df_hourly_weather['UTC_DATE'].min()) + ' to '+ str(df_hourly_weather['UTC_DATE'].max()))

df_hourly_weather.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1135 entries, 0 to 1134
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   x                       1135 non-null   float64
#  1   y                       1135 non-null   float64
#  2   LOCAL_HOUR              1135 non-null   int64
#  3   WEATHER_ENG_DESC        72 non-null     object
#  4   WIND_DIRECTION          1084 non-null   float64
#  5   WINDCHILL               0 non-null      float64
#  6   PRECIP_AMOUNT           1135 non-null   float64
#  7   DEW_POINT_TEMP_FLAG     0 non-null      float64
#  8   HUMIDEX                 257 non-null    float64
#  9   ID                      1135 non-null   object
#  10  VISIBILITY_FLAG         0 non-null      float64
#  11  CLIMATE_IDENTIFIER      1135 non-null   int64
#  12  WIND_SPEED_FLAG         0 non-null      float64
#  13  RELATIVE_HUMIDITY       1135 non-null   int64
# ...
